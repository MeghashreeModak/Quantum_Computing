# %%
import matplotlib.pyplot as plt

x = []
y = []

def mataga_nishimoto(unit_dist, U, irange, jrange):
    sum = 0
    for i in range(1, irange+1):
        for j in range(i+1, jrange+1):
            if i != j:
                rij = (j-i)*unit_dist
                x.append(rij)
                gamma = 1/((1/U)+rij)
                y.append(gamma)
                print(f"gamma{i}{j}: {gamma}")

fun(1, 3, 10, 10)
plt.scatter(x,y)
# Out:
# gamma12: 0.75
# gamma13: 0.42857142857142855
# gamma14: 0.3
# gamma15: 0.23076923076923078
# gamma16: 0.1875
# gamma17: 0.15789473684210528
# gamma18: 0.13636363636363638
# gamma19: 0.12
# gamma110: 0.10714285714285714
# gamma23: 0.75
# gamma24: 0.42857142857142855
# gamma25: 0.3
# gamma26: 0.23076923076923078
# gamma27: 0.1875
# gamma28: 0.15789473684210528
# gamma29: 0.13636363636363638
# gamma210: 0.12
# gamma34: 0.75
# gamma35: 0.42857142857142855
# gamma36: 0.3
# gamma37: 0.23076923076923078
# gamma38: 0.1875
# gamma39: 0.15789473684210528
# gamma310: 0.13636363636363638
# gamma45: 0.75
# gamma46: 0.42857142857142855
# gamma47: 0.3
# gamma48: 0.23076923076923078
# gamma49: 0.1875
# gamma410: 0.15789473684210528
# gamma56: 0.75
# gamma57: 0.42857142857142855
# gamma58: 0.3
# gamma59: 0.23076923076923078
# gamma510: 0.1875
# gamma67: 0.75
# gamma68: 0.42857142857142855
# gamma69: 0.3
# gamma610: 0.23076923076923078
# gamma78: 0.75
# gamma79: 0.42857142857142855
# gamma710: 0.3
# gamma89: 0.75
# gamma810: 0.42857142857142855
# gamma910: 0.75
